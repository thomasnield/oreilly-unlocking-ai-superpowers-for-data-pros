# %% [markdown]
# If you navigate for tornados in a specific state on the NOAA site https://www.ncei.noaa.gov/, you will get a url like this pattern

# %%
import pandas as pd

url = r"https://www.ncei.noaa.gov/stormevents/csv?eventType=%28C%29+Tornado&beginDate_mm=05&beginDate_dd=01&beginDate_yyyy=2024&endDate_mm=05&endDate_dd=31&endDate_yyyy=2025&county=ALL&hailfilter=0.00&tornfilter=0&windfilter=000&sort=DT&submitbutton=Search&statefips=48%2CTEXAS"
df = pd.read_csv(url, dtype={"BEGIN_TIME" : str, "END_TIME" : str})

df
# Out:
#      EVENT_ID     CZ_NAME_STR BEGIN_LOCATION  BEGIN_DATE BEGIN_TIME  \
# 0     1175479      DONLEY CO.      CLARENDON  05/01/2024       1456
# 1     1175480      DONLEY CO.        ASHTOLA  05/01/2024       1504
# 2     1175474  HUTCHINSON CO.        PRINGLE  05/01/2024       1614
# 3     1166279        HALL CO.         TURKEY  05/01/2024       1649
# 4     1175475    HANSFORD CO.       SPEARMAN  05/01/2024       1743
# ..        ...             ...            ...         ...        ...
# 203   1267458      MENARD CO.         MENARD  05/26/2025       1513
# 204   1265149      CARSON CO.     WHITE DEER  05/26/2025       1733
# 205   1260975      DAWSON CO.  PUNKIN CENTER  05/29/2025       1709
# 206   1260976      DAWSON CO.     SPARENBURG  05/29/2025       1746
# 207   1267460     COLEMAN CO.      GLEN COVE  05/29/2025       2031
#
#     EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  ...  \
# 0      Tornado                   EF0              0                0  ...
# ...

# %% [markdown]
# See if we can have AI modify this code so it figures out the URL's for all 50 states, and we can download them all into a single dataframe. Don't be surprised if we have to do a little debugging and troubleshooting!

# %%
# put code here

# %% [markdown]
# Verify the data by seeing how many states and the count of records occur in each one.

# %%
# put code here

# %% [markdown]
# Now let's see if we can get greedy. NOAA will cut off datasets at 500 records so we cannot use too large of date ranges for a given state. But what if we queried one date at a time for every state?

# %%
# Out:
# Successfully downloaded data for KANSAS on 2024-05-01
# Successfully downloaded data for LOUISIANA on 2024-05-02
# Successfully downloaded data for MISSOURI on 2024-05-02
# Successfully downloaded data for OKLAHOMA on 2024-05-01
# Successfully downloaded data for TEXAS on 2024-05-01
# Successfully downloaded data for TEXAS on 2024-05-02
# Successfully downloaded data for WASHINGTON on 2024-05-01
#     EVENT_ID           CZ_NAME_STR        BEGIN_LOCATION  BEGIN_DATE  \
# 0    1176393              GOVE CO.                  GOVE  05/01/2024
# 1    1176512              GOVE CO.                  GOVE  05/01/2024
# 2    1213042              LANE CO.             PENDENNIS  05/01/2024
# 3    1185126           SABINE PAR.             FT JESSUP  05/02/2024
# 4    1182535  JEFFERSON DAVIS PAR.            WELSH ARPT  05/02/2024
# 5    1167379            JASPER CO.  (JLN)JOPLIN MUNI ARP  05/02/2024
# 6    1184070          COMANCHE CO.                 FAXON  05/01/2024
# ...

# %% [markdown]
# After that, put the data into a SQLite database.
